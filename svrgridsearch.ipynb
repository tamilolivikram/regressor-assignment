# %%
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-312f3ab09c1b> in <module>
# ----> 1 dataset=pd.get_dummies(dataset,drop_first=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     868         # determine columns being encoded
#     869         if columns is None:
# --> 870             data_to_encode = data.select_dtypes(include=dtypes_to_encode)
#     871         else:
#     872             data_to_encode = data[columns]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in select_dtypes(self, include, exclude)
#    3425         # the "union" of the logic of case 1 and case 2:
#    3426         # we get the included and excluded, and return their logical and
# -> 3427         include_these = Series(not bool(include), index=self.columns)
# ...
